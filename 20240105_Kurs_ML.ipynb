# %% [markdown]
# <a href="https://colab.research.google.com/github/MBKwiatkowska/mlb-colab/blob/main/20240105_Kurs_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#https://www.udemy.com/course/machine-learning-bootcamp-w-jezyku-python/?utm_source=adwords&utm_medium=udemyads&utm_campaign=INTL-AW-PROS-TECH-Poland-DSA-WebIndex&utm_term=_._ag_100563868518_._ad_427601021502_._de_c_._dm__._pl__._ti_dsa-93451758763_._li_9061064_._pd__._&gad_source=1&gclid=CjwKCAiA7t6sBhAiEiwAsaieYrCDGG_NS85bRP6MsEp1B454NU_kxwdQXgfXvB3J1lC-FWQkWDIDdhoCrd0QAvD_BwE
# Out:
#   File "<ipython-input-3-b9cb45502bbc>", line 3
#     pip install scikit-learn
#         ^
# SyntaxError: invalid syntax

# %%
#!pip install scikit-learn

import numpy as np
import pandas as pd
import sklearn

sklearn.__version__
# Out:
# '1.2.2'

# %%
data = {
    'size': ['XL', 'L', 'M', 'L', 'M'],
    'color': ['red', 'green', 'blue', 'green', 'red'],
    'gender': ['female', 'male', 'male', 'female', 'female'],
    'price': [199.0, 89.0, 99.0, 129.0, 79.0],
    'weight': [500, 450, 300, 380, 410],
    'bought': ['yes', 'no', 'yes', 'no', 'yes']
}

df_raw = pd.DataFrame(data=data)
df_raw
# Out:
#   size  color  gender  price  weight bought
# 0   XL    red  female  199.0     500    yes
# 1    L  green    male   89.0     450     no
# 2    M   blue    male   99.0     300    yes
# 3    L  green  female  129.0     380     no
# 4    M    red  female   79.0     410    yes

# %%
df = df_raw.copy()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   size    5 non-null      object
#  1   color   5 non-null      object
#  2   gender  5 non-null      object
#  3   price   5 non-null      float64
#  4   weight  5 non-null      int64
#  5   bought  5 non-null      object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 368.0+ bytes

# %% [markdown]
# przewidywanie targetu (bought) na podstawie 5 atrybutow - size,color, gender, prcie, weight

# %%
for col in ['size', 'color', 'gender', 'bought']:
    df[col] = df[col].astype('category')

df['weight'] = df['weight'].astype('float')

df.info()

df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   size    5 non-null      category
#  1   color   5 non-null      category
#  2   gender  5 non-null      category
#  3   price   5 non-null      float64
#  4   weight  5 non-null      float64
#  5   bought  5 non-null      category
# dtypes: category(4), float64(2)
# memory usage: 740.0 bytes
#             price      weight
# count    5.000000    5.000000
# mean   119.000000  408.000000
# std     48.476799   75.299402
# min     79.000000  300.000000
# 25%     89.000000  380.000000
# 50%     99.000000  410.000000
# 75%    129.000000  450.000000
# max    199.000000  500.000000

# %%
pd.get_dummies(df) #zmienne kategoryczne na 1/0
# Out:
#    price  weight  size_L  size_M  size_XL  color_blue  color_green  color_red  \
# 0    199     500       0       0        1           0            0          1
# 1     89     450       1       0        0           0            1          0
# 2     99     300       0       1        0           1            0          0
# 3    129     438       1       0        0           0            1          0
# 4     79     410       0       1        0           0            0          1
#
#    gender_female  gender_male  bought_no  bought_yes
# 0              1            0          0           1
# 1              0            1          1           0
# 2              0            1          0           1
# 3              1            0          1           0
# 4              1            0          0           1

# %% [markdown]
# Standardyzacja

# %%
df['price'] = (df['price'] - df['price'].mean()) / df['price'].std()
df['weight'] = (df['weight'] - df['weight'].mean()) / df['weight'].std()

# %%
df
# Out:
#   size  color  gender     price    weight bought
# 0   XL    red  female  1.650274  1.081091    yes
# 1    L  green    male -0.618853  0.408771     no
# 2    M   blue    male -0.412568 -1.608189    yes
# 3    L  green  female  0.206284  0.247414     no
# 4    M    red  female -0.825137 -0.129085    yes

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
le.fit(df['bought'])
le.transform(df['bought'])

# %%
df['bought'] = le.fit_transform(df['bought'])
df
# Out:
#   size  color  gender  price  weight  bought
# 0   XL    red  female  199.0   500.0       1
# 1    L  green    male   89.0   450.0       0
# 2    M   blue    male   99.0   300.0       1
# 3    L  green  female  129.0   380.0       0
# 4    M    red  female   79.0   410.0       1

# %%
le.inverse_transform(df['bought'])
# Out:
# array(['yes', 'no', 'yes', 'no', 'yes'], dtype=object)

# %%
pd.get_dummies(df)
# Out:
#    price  weight  bought  size_L  size_M  size_XL  color_blue  color_green  \
# 0  199.0   500.0       1       0       0        1           0            0
# 1   89.0   450.0       0       1       0        0           0            1
# 2   99.0   300.0       1       0       1        0           1            0
# 3  129.0   380.0       0       1       0        0           0            1
# 4   79.0   410.0       1       0       1        0           0            0
#
#    color_red  gender_female  gender_male
# 0          1              1            0
# 1          0              0            1
# 2          0              0            1
# 3          0              1            0
# 4          1              1            0

# %%
pd.get_dummies(df, drop_first= True)
# Out:
#    price  weight  bought  size_M  size_XL  color_green  color_red  gender_male
# 0  199.0   500.0       1       0        1            0          1            0
# 1   89.0   450.0       0       0        0            1          0            1
# 2   99.0   300.0       1       1        0            0          0            1
# 3  129.0   380.0       0       0        0            1          0            0
# 4   79.0   410.0       1       1        0            0          1            0
